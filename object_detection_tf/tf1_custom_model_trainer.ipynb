# %% [markdown]
# # Customizable object detector model with TF1 API

# %% [markdown]
# ## Workspace preparation

# %%
# %tensorflow_version 1.x

! git clone --depth 1 https://github.com/tensorflow/models
! pip install -q tf_slim
! pip install -qq pycocotools

# %cd /content/models/research/
! protoc object_detection/protos/*.proto --python_out=.

from google.colab import drive
drive.mount('/content/drive')
# !rm -rf /content/sample_data
# Out:
# TensorFlow 1.x selected.
# Cloning into 'models'...
# remote: Enumerating objects: 2232, done.
# remote: Counting objects: 100% (2232/2232), done.
# remote: Compressing objects: 100% (1930/1930), done.
# remote: Total 2232 (delta 541), reused 976 (delta 277), pack-reused 0
# Receiving objects: 100% (2232/2232), 30.48 MiB | 24.54 MiB/s, done.
# Resolving deltas: 100% (541/541), done.
#      |████████████████████████████████| 358kB 5.1MB/s
# /content/models/research
# Mounted at /content/drive

# %%
import os
import time

os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/:/content/models/research/slim/'

from google.protobuf import text_format
from object_detection.utils import config_util

# %cd /content/drive/My Drive/projects/ML/object_detection_tf/workspace
# Out:
# /content/drive/My Drive/projects/ML/object_detection_tf/workspace

# %% [markdown]
# ## Model selection

# %%
selected_model = "faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28" #@param ["ssd_mobilenet_v2_quantized_300x300", "ssd_mobilenet_v3_small_coco", "ssdlite_mobilenet_edgetpu_coco_quant", "faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28"]
pipeline_path = f'my_models/pipelines/{selected_model}.config'
output_model_dir = f'my_models/{selected_model}/'

# %% [markdown]
# ## Pipeline adjustments

# %%
# Getting configs from pipeline file
configs = config_util.get_configs_from_pipeline_file(pipeline_path)
pipeline_config = config_util.create_pipeline_proto_from_configs(configs)
pipeline_config
# Out:
# model {
#   faster_rcnn {
#     num_classes: 1
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: "faster_rcnn_inception_resnet_v2"
#       first_stage_features_stride: 8
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         height_stride: 8
#         width_stride: 8
#         scales: 0.25
#         scales: 0.5
#         scales: 1.0
#         scales: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#       }
#     }
#     first_stage_atrous_rate: 2
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.009990000165998936
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.6990000009536743
#     first_stage_max_proposals: 1000
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     initial_crop_size: 17
#     maxpool_kernel_size: 1
#     maxpool_stride: 1
#     second_stage_box_predictor {
#       mask_rcnn_box_predictor {
#         fc_hyperparams {
#           op: FC
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             variance_scaling_initializer {
#               factor: 1.0
#               uniform: true
#               mode: FAN_AVG
#             }
#           }
#         }
#         use_dropout: false
#         dropout_keep_probability: 1.0
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.30000001192092896
#         iou_threshold: 0.6000000238418579
#         max_detections_per_class: 800
#         max_total_detections: 800
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#   }
# }
# train_config {
#   batch_size: 1
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   optimizer {
#     momentum_optimizer {
#       learning_rate {
#         cosine_decay_learning_rate {
#           learning_rate_base: 0.03999999910593033
#           total_steps: 4000
#           warmup_learning_rate: 0.013000000268220901
#           warmup_steps: 100
#         }
#       }
#       momentum_optimizer_value: 0.8999000191688538
#     }
#     use_moving_average: false
#   }
#   gradient_clipping_by_norm: 10.0
#   fine_tune_checkpoint: "pre_trained_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/ckpt-0"
#   from_detection_checkpoint: true
#   num_steps: 4000
#   max_number_of_boxes: 800
# }
# train_input_reader {
#   label_map_path: "annotations/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "annotations/train.tfrecord"
#   }
#   max_number_of_boxes: 800
# }
# eval_config {
#   use_moving_averages: false
#   max_num_boxes_to_visualize: 800
#   batch_size: 1
# }
# eval_input_reader {
#   label_map_path: "annotations/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
#   tf_record_input_reader {
#     input_path: "annotations/test.tfrecord"
#   }
#   max_number_of_boxes: 800
# }

# %%
# %%writefile {pipeline_path}
#
# model {
#   faster_rcnn {
#     num_classes: 1
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: "faster_rcnn_inception_resnet_v2"
#       first_stage_features_stride: 8
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         height_stride: 8
#         width_stride: 8
#         scales: 0.25
#         scales: 0.5
#         scales: 1.0
#         scales: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#       }
#     }
#     first_stage_atrous_rate: 2
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.00999
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.699
#     first_stage_max_proposals: 1000
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     initial_crop_size: 17
#     maxpool_kernel_size: 1
#     maxpool_stride: 1
#     second_stage_box_predictor {
#       mask_rcnn_box_predictor {
#         fc_hyperparams {
#           op: FC
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             variance_scaling_initializer {
#               factor: 1.0
#               uniform: true
#               mode: FAN_AVG
#             }
#           }
#         }
#         use_dropout: false
#         dropout_keep_probability: 1.0
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.3
#         iou_threshold: 0.6
#         max_detections_per_class: 800
#         max_total_detections: 800
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#   }
# }
# train_config {
#   batch_size: 1
#   max_number_of_boxes: 800
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   optimizer {
#     momentum_optimizer {
#       learning_rate {
#         cosine_decay_learning_rate {
#           learning_rate_base: 0.04
#           total_steps: 10000
#           warmup_learning_rate: 0.013
#           warmup_steps: 100
#         }
#       }
#       momentum_optimizer_value: 0.8999
#     }
#     use_moving_average: false
#   }
#   gradient_clipping_by_norm: 10.0
#   fine_tune_checkpoint: "pre_trained_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/ckpt-0"
#   from_detection_checkpoint: true
#   num_steps: 10000
# }
# train_input_reader {
#   label_map_path: "annotations/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "annotations/train.tfrecord"
#   }
#   max_number_of_boxes: 800
#
# }
# eval_config {
#   batch_size: 1
#   use_moving_averages: false
#   max_num_boxes_to_visualize: 800
# }
# eval_input_reader {
#   label_map_path: "annotations/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
#   tf_record_input_reader {
#     input_path: "annotations/test.tfrecord"
#   }
#   max_number_of_boxes: 800
#
# }
# Out:
# Overwriting my_models/pipelines/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28.config

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Training the model

# %%
start_time = time.time()

# !python3 /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={pipeline_path}\
    --model_dir={output_model_dir} \
    --num_train_steps=10000 \
    --sample_1_of_n_eval_examples=1 \
    --alsologtostderr

end_time = time.time()
elapsed_time = end_time - start_time
print(f'Elapsed time: {int(elapsed_time/60)}m')
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1008 22:44:37.358770 140205958432640 model_lib.py:771] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I1008 22:44:37.358992 140205958432640 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1008 22:44:37.359091 140205958432640 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I1008 22:44:37.359170 140205958432640 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1008 22:44:37.359249 140205958432640 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1008 22:44:37.359371 140205958432640 model_lib.py:787] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:create_estimator_and_inputs: use_tpu False, export_to_tpu None
# I1008 22:44:37.359575 140205958432640 model_lib.py:822] create_estimator_and_inputs: use_tpu False, export_to_tpu None
# INFO:tensorflow:Using config: {'_model_dir': 'my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f83d2e75668>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I1008 22:44:37.360020 140205958432640 estimator.py:212] Using config: {'_model_dir': 'my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f83d2e75668>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7f83d2e1c840>) includes params argument, but params are not passed to Estimator.
# W1008 22:44:37.360224 140205958432640 model_fn.py:630] Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7f83d2e1c840>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Not using Distribute Coordinator.
# I1008 22:44:37.361068 140205958432640 estimator_training.py:186] Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# I1008 22:44:37.361258 140205958432640 training.py:612] Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# I1008 22:44:37.361525 140205958432640 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W1008 22:44:37.604101 140205958432640 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Reading unweighted datasets: ['annotations/train.tfrecord']
# I1008 22:44:37.641232 140205958432640 dataset_builder.py:148] Reading unweighted datasets: ['annotations/train.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/train.tfrecord']
# I1008 22:44:37.642842 140205958432640 dataset_builder.py:77] Reading record datasets for input file: ['annotations/train.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1008 22:44:37.642994 140205958432640 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1008 22:44:37.643083 140205958432640 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:103: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W1008 22:44:37.648599 140205958432640 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:103: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:222: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1008 22:44:37.669849 140205958432640 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:222: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f83d0d817f0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W1008 22:44:37.704092 140205958432640 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f83d0d817f0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function train_input.<locals>.transform_and_pad_input_data_fn at 0x7f83d2e1cbf8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W1008 22:44:37.896188 140205958432640 ag_logging.py:146] Entity <function train_input.<locals>.transform_and_pad_input_data_fn at 0x7f83d2e1cbf8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:80: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1008 22:44:37.904534 140205958432640 deprecation.py:323] From /content/models/research/object_detection/inputs.py:80: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1008 22:44:37.914287 140205958432640 deprecation.py:323] From /content/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:261: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1008 22:44:38.038432 140205958432640 deprecation.py:323] From /content/models/research/object_detection/inputs.py:261: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Calling model_fn.
# I1008 22:44:38.418658 140205958432640 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:38.440674 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:38.440848 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1008 22:44:38.441664 140205958432640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:46.728587 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:46.912253 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1008 22:44:46.912686 140205958432640 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/utils/spatial_transform_ops.py:478: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W1008 22:44:47.682199 140205958432640 deprecation.py:506] From /content/models/research/object_detection/utils/spatial_transform_ops.py:478: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:47.697047 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:47.697250 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1666: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W1008 22:44:49.021565 140205958432640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1666: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:49.023828 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:44:49.040303 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:380: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W1008 22:44:49.340875 140205958432640 deprecation.py:323] From /content/models/research/object_detection/core/losses.py:380: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:tensorflow:Done calling model_fn.
# I1008 22:44:58.645213 140205958432640 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I1008 22:44:58.646634 140205958432640 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# I1008 22:45:03.372673 140205958432640 monitored_session.py:240] Graph was finalized.
# 2020-10-08 22:45:03.384413: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-10-08 22:45:03.384643: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2bb39c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-08 22:45:03.384691: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-08 22:45:03.389241: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-08 22:45:03.570987: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:45:03.571694: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2bb3100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-08 22:45:03.571724: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-10-08 22:45:03.572609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:45:03.573183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-10-08 22:45:03.573605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-08 22:45:03.817332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-08 22:45:03.946069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-08 22:45:03.981199: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-08 22:45:04.217621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-08 22:45:04.280408: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-08 22:45:04.742900: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-08 22:45:04.743123: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:45:04.743894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:45:04.744448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-10-08 22:45:04.747304: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-08 22:45:04.748797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-08 22:45:04.748829: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-10-08 22:45:04.748841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-10-08 22:45:04.774757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:45:04.775421: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:45:04.775996: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-08 22:45:04.776042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-500
# I1008 22:45:04.780273 140205958432640 saver.py:1284] Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-500
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# W1008 22:45:17.215970 140205958432640 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# I1008 22:45:18.921125 140205958432640 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1008 22:45:19.365364 140205958432640 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 500 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# I1008 22:45:32.780738 140205958432640 basic_session_run_hooks.py:606] Saving checkpoints for 500 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# 2020-10-08 22:45:52.157108: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-08 22:46:00.602134: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# INFO:tensorflow:loss = 4.324239, step = 500
# I1008 22:46:14.004050 140205958432640 basic_session_run_hooks.py:262] loss = 4.324239, step = 500
# INFO:tensorflow:global_step/sec: 0.749904
# I1008 22:48:27.353722 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.749904
# INFO:tensorflow:loss = 4.491297, step = 600 (133.351 sec)
# I1008 22:48:27.355372 140205958432640 basic_session_run_hooks.py:260] loss = 4.491297, step = 600 (133.351 sec)
# INFO:tensorflow:global_step/sec: 0.794526
# I1008 22:50:33.214979 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.794526
# INFO:tensorflow:loss = 3.3761754, step = 700 (125.861 sec)
# I1008 22:50:33.216708 140205958432640 basic_session_run_hooks.py:260] loss = 3.3761754, step = 700 (125.861 sec)
# INFO:tensorflow:global_step/sec: 0.778882
# I1008 22:52:41.604148 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.778882
# INFO:tensorflow:loss = 4.604298, step = 800 (128.389 sec)
# I1008 22:52:41.606038 140205958432640 basic_session_run_hooks.py:260] loss = 4.604298, step = 800 (128.389 sec)
# INFO:tensorflow:global_step/sec: 0.77769
# I1008 22:54:50.190132 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.77769
# INFO:tensorflow:loss = 3.4407008, step = 900 (128.586 sec)
# I1008 22:54:50.191870 140205958432640 basic_session_run_hooks.py:260] loss = 3.4407008, step = 900 (128.586 sec)
# INFO:tensorflow:Saving checkpoints for 938 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# I1008 22:55:37.775142 140205958432640 basic_session_run_hooks.py:606] Saving checkpoints for 938 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['annotations/test.tfrecord']
# I1008 22:55:42.006990 140205958432640 dataset_builder.py:148] Reading unweighted datasets: ['annotations/test.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/test.tfrecord']
# I1008 22:55:42.009527 140205958432640 dataset_builder.py:77] Reading record datasets for input file: ['annotations/test.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1008 22:55:42.009663 140205958432640 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f83ac0a1eb8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W1008 22:55:42.061661 140205958432640 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f83ac0a1eb8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f83c9db59d8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W1008 22:55:42.243020 140205958432640 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f83c9db59d8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I1008 22:55:42.763230 140205958432640 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:42.785420 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:42.785582 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:50.641174 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:51.135934 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1008 22:55:51.136357 140205958432640 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:51.681307 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:51.681538 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:53.135280 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 22:55:53.154731 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/eval_util.py:879: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1008 22:55:54.192565 140205958432640 deprecation.py:323] From /content/models/research/object_detection/eval_util.py:879: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/visualization_utils.py:618: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W1008 22:55:54.415902 140205958432640 deprecation.py:323] From /content/models/research/object_detection/utils/visualization_utils.py:618: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Done calling model_fn.
# I1008 22:55:55.385402 140205958432640 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-08T22:55:55Z
# I1008 22:55:55.400813 140205958432640 evaluation.py:255] Starting evaluation at 2020-10-08T22:55:55Z
# INFO:tensorflow:Graph was finalized.
# I1008 22:55:56.411740 140205958432640 monitored_session.py:240] Graph was finalized.
# 2020-10-08 22:55:56.413020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:55:56.413394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-10-08 22:55:56.413504: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-08 22:55:56.413535: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-08 22:55:56.413560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-08 22:55:56.413584: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-08 22:55:56.413606: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-08 22:55:56.413626: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-08 22:55:56.413649: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-08 22:55:56.413729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:55:56.414064: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:55:56.414355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-10-08 22:55:56.414408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-08 22:55:56.414421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-10-08 22:55:56.414431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-10-08 22:55:56.414530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:55:56.414859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 22:55:56.415144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-938
# I1008 22:55:56.416939 140205958432640 saver.py:1284] Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-938
# INFO:tensorflow:Running local_init_op.
# I1008 22:55:59.425170 140205958432640 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1008 22:55:59.766847 140205958432640 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 7 images.
# I1008 22:57:52.187339 140203523565312 coco_evaluation.py:282] Performing evaluation on 7 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1008 22:57:52.188940 140203523565312 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I1008 22:57:52.191571 140203523565312 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.59s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# INFO:tensorflow:Finished evaluation at 2020-10-08-22:58:05
# I1008 22:58:05.044549 140205958432640 evaluation.py:275] Finished evaluation at 2020-10-08-22:58:05
# INFO:tensorflow:Saving dict for global step 938: DetectionBoxes_Precision/mAP = 0.0, DetectionBoxes_Precision/mAP (large) = 0.0, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.0, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0, DetectionBoxes_Recall/AR@100 = 0.0, DetectionBoxes_Recall/AR@100 (large) = 0.0, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.34606537, Loss/BoxClassifierLoss/localization_loss = 0.24712846, Loss/RPNLoss/localization_loss = 2.4461691, Loss/RPNLoss/objectness_loss = 0.32384697, Loss/total_loss = 3.36321, global_step = 938, learning_rate = 0.03561364, loss = 3.36321
# I1008 22:58:05.044851 140205958432640 estimator.py:2049] Saving dict for global step 938: DetectionBoxes_Precision/mAP = 0.0, DetectionBoxes_Precision/mAP (large) = 0.0, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.0, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0, DetectionBoxes_Recall/AR@100 = 0.0, DetectionBoxes_Recall/AR@100 (large) = 0.0, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.34606537, Loss/BoxClassifierLoss/localization_loss = 0.24712846, Loss/RPNLoss/localization_loss = 2.4461691, Loss/RPNLoss/objectness_loss = 0.32384697, Loss/total_loss = 3.36321, global_step = 938, learning_rate = 0.03561364, loss = 3.36321
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 938: my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-938
# I1008 22:58:07.279683 140205958432640 estimator.py:2109] Saving 'checkpoint_path' summary for global step 938: my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-938
# INFO:tensorflow:global_step/sec: 0.364578
# I1008 22:59:24.479639 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.364578
# INFO:tensorflow:loss = 4.321583, step = 1000 (274.289 sec)
# I1008 22:59:24.481309 140205958432640 basic_session_run_hooks.py:260] loss = 4.321583, step = 1000 (274.289 sec)
# INFO:tensorflow:global_step/sec: 0.795556
# I1008 23:01:30.177869 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.795556
# INFO:tensorflow:loss = 4.1105127, step = 1100 (125.698 sec)
# I1008 23:01:30.179401 140205958432640 basic_session_run_hooks.py:260] loss = 4.1105127, step = 1100 (125.698 sec)
# INFO:tensorflow:global_step/sec: 0.779709
# I1008 23:03:38.430779 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.779709
# INFO:tensorflow:loss = 3.5063095, step = 1200 (128.253 sec)
# I1008 23:03:38.432544 140205958432640 basic_session_run_hooks.py:260] loss = 3.5063095, step = 1200 (128.253 sec)
# INFO:tensorflow:Saving checkpoints for 1295 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# I1008 23:05:38.934064 140205958432640 basic_session_run_hooks.py:606] Saving checkpoints for 1295 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['annotations/test.tfrecord']
# I1008 23:05:42.502208 140205958432640 dataset_builder.py:148] Reading unweighted datasets: ['annotations/test.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/test.tfrecord']
# I1008 23:05:42.503561 140205958432640 dataset_builder.py:77] Reading record datasets for input file: ['annotations/test.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1008 23:05:42.503692 140205958432640 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f836062e978>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W1008 23:05:42.543577 140205958432640 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f836062e978>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f8038a24ae8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W1008 23:05:42.704605 140205958432640 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f8038a24ae8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I1008 23:05:43.215892 140205958432640 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:43.237697 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:43.237862 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:51.776571 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:51.982368 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1008 23:05:51.982756 140205958432640 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:52.558254 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:52.558460 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:54.052875 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1008 23:05:54.070463 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I1008 23:05:56.274607 140205958432640 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-08T23:05:56Z
# I1008 23:05:56.290268 140205958432640 evaluation.py:255] Starting evaluation at 2020-10-08T23:05:56Z
# INFO:tensorflow:Graph was finalized.
# I1008 23:05:57.304679 140205958432640 monitored_session.py:240] Graph was finalized.
# 2020-10-08 23:05:57.305452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 23:05:57.305837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-10-08 23:05:57.318898: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-08 23:05:57.318995: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-08 23:05:57.319021: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-08 23:05:57.319042: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-08 23:05:57.319063: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-08 23:05:57.319083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-08 23:05:57.319105: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-08 23:05:57.319205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 23:05:57.319662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 23:05:57.319954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-10-08 23:05:57.320847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-08 23:05:57.320872: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-10-08 23:05:57.320883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-10-08 23:05:57.321013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 23:05:57.321382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-08 23:05:57.321694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-1295
# I1008 23:05:57.323779 140205958432640 saver.py:1284] Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-1295
# INFO:tensorflow:Running local_init_op.
# I1008 23:06:00.332958 140205958432640 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1008 23:06:00.694988 140205958432640 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 7 images.
# I1008 23:07:56.288139 140203523565312 coco_evaluation.py:282] Performing evaluation on 7 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1008 23:07:56.290895 140203523565312 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I1008 23:07:56.295082 140203523565312 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.30s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# INFO:tensorflow:Finished evaluation at 2020-10-09-00:58:14
# I1009 00:58:14.697503 140205958432640 evaluation.py:275] Finished evaluation at 2020-10-09-00:58:14
# INFO:tensorflow:Saving dict for global step 5270: DetectionBoxes_Precision/mAP = 0.0, DetectionBoxes_Precision/mAP (large) = 0.0, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.0, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0, DetectionBoxes_Recall/AR@100 = 0.0, DetectionBoxes_Recall/AR@100 (large) = 0.0, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.3503029, Loss/BoxClassifierLoss/localization_loss = 0.25477797, Loss/RPNLoss/localization_loss = 2.41096, Loss/RPNLoss/objectness_loss = 0.31385103, Loss/total_loss = 3.3298917, global_step = 5270, learning_rate = 0.0, loss = 3.3298917
# I1009 00:58:14.697797 140205958432640 estimator.py:2049] Saving dict for global step 5270: DetectionBoxes_Precision/mAP = 0.0, DetectionBoxes_Precision/mAP (large) = 0.0, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.0, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0, DetectionBoxes_Recall/AR@100 = 0.0, DetectionBoxes_Recall/AR@100 (large) = 0.0, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.3503029, Loss/BoxClassifierLoss/localization_loss = 0.25477797, Loss/RPNLoss/localization_loss = 2.41096, Loss/RPNLoss/objectness_loss = 0.31385103, Loss/total_loss = 3.3298917, global_step = 5270, learning_rate = 0.0, loss = 3.3298917
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5270: my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-5270
# I1009 00:58:14.752269 140205958432640 estimator.py:2109] Saving 'checkpoint_path' summary for global step 5270: my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-5270
# INFO:tensorflow:global_step/sec: 0.364217
# I1009 00:58:52.516117 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.364217
# INFO:tensorflow:loss = 3.6115813, step = 5300 (274.562 sec)
# I1009 00:58:52.517731 140205958432640 basic_session_run_hooks.py:260] loss = 3.6115813, step = 5300 (274.562 sec)
# INFO:tensorflow:global_step/sec: 0.798738
# I1009 01:00:57.713564 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.798738
# INFO:tensorflow:loss = 3.3481069, step = 5400 (125.197 sec)
# I1009 01:00:57.714993 140205958432640 basic_session_run_hooks.py:260] loss = 3.3481069, step = 5400 (125.197 sec)
# INFO:tensorflow:global_step/sec: 0.781972
# I1009 01:03:05.595372 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.781972
# INFO:tensorflow:loss = 3.1734762, step = 5500 (127.882 sec)
# I1009 01:03:05.596892 140205958432640 basic_session_run_hooks.py:260] loss = 3.1734762, step = 5500 (127.882 sec)
# INFO:tensorflow:global_step/sec: 0.782243
# I1009 01:05:13.432971 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.782243
# INFO:tensorflow:loss = 3.5501926, step = 5600 (127.838 sec)
# I1009 01:05:13.434745 140205958432640 basic_session_run_hooks.py:260] loss = 3.5501926, step = 5600 (127.838 sec)
# INFO:tensorflow:Saving checkpoints for 5627 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# I1009 01:05:46.782010 140205958432640 basic_session_run_hooks.py:606] Saving checkpoints for 5627 into my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['annotations/test.tfrecord']
# I1009 01:05:50.551201 140205958432640 dataset_builder.py:148] Reading unweighted datasets: ['annotations/test.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['annotations/test.tfrecord']
# I1009 01:05:50.554686 140205958432640 dataset_builder.py:77] Reading record datasets for input file: ['annotations/test.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1009 01:05:50.554837 140205958432640 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f80388dbdd8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W1009 01:05:50.597278 140205958432640 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f80388dbdd8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f80391a5950> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W1009 01:05:50.760129 140205958432640 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f80391a5950> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I1009 01:05:51.269460 140205958432640 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:05:51.290376 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:05:51.290523 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:05:59.275113 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:05:59.462853 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1009 01:05:59.463238 140205958432640 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:06:00.032197 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:06:00.032465 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:06:01.922192 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I1009 01:06:01.937747 140205958432640 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Done calling model_fn.
# I1009 01:06:03.848810 140205958432640 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-09T01:06:03Z
# I1009 01:06:03.863790 140205958432640 evaluation.py:255] Starting evaluation at 2020-10-09T01:06:03Z
# INFO:tensorflow:Graph was finalized.
# I1009 01:06:04.862273 140205958432640 monitored_session.py:240] Graph was finalized.
# 2020-10-09 01:06:04.863221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-09 01:06:04.863611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-10-09 01:06:04.863714: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-09 01:06:04.863746: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-10-09 01:06:04.863768: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-10-09 01:06:04.863788: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-10-09 01:06:04.863807: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-10-09 01:06:04.863826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-10-09 01:06:04.863846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-09 01:06:04.863936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-09 01:06:04.864266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-09 01:06:04.864549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-10-09 01:06:04.864707: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-09 01:06:04.864722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-10-09 01:06:04.864732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-10-09 01:06:04.864844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-09 01:06:04.865187: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-09 01:06:04.865483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-5627
# I1009 01:06:04.867685 140205958432640 saver.py:1284] Restoring parameters from my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-5627
# INFO:tensorflow:Running local_init_op.
# I1009 01:06:07.976456 140205958432640 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1009 01:06:08.352174 140205958432640 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 7 images.
# I1009 01:08:02.365193 140203523565312 coco_evaluation.py:282] Performing evaluation on 7 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1009 01:08:02.367539 140203523565312 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I1009 01:08:02.370057 140203523565312 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.45s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# INFO:tensorflow:Finished evaluation at 2020-10-09-01:08:15
# I1009 01:08:15.077793 140205958432640 evaluation.py:275] Finished evaluation at 2020-10-09-01:08:15
# INFO:tensorflow:Saving dict for global step 5627: DetectionBoxes_Precision/mAP = 0.0, DetectionBoxes_Precision/mAP (large) = 0.0, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.0, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0, DetectionBoxes_Recall/AR@100 = 0.0, DetectionBoxes_Recall/AR@100 (large) = 0.0, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.3503029, Loss/BoxClassifierLoss/localization_loss = 0.25477797, Loss/RPNLoss/localization_loss = 2.490097, Loss/RPNLoss/objectness_loss = 0.30091414, Loss/total_loss = 3.3960922, global_step = 5627, learning_rate = 0.0, loss = 3.3960922
# I1009 01:08:15.078074 140205958432640 estimator.py:2049] Saving dict for global step 5627: DetectionBoxes_Precision/mAP = 0.0, DetectionBoxes_Precision/mAP (large) = 0.0, DetectionBoxes_Precision/mAP (medium) = 0.0, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.0, DetectionBoxes_Precision/mAP@.75IOU = 0.0, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0, DetectionBoxes_Recall/AR@100 = 0.0, DetectionBoxes_Recall/AR@100 (large) = 0.0, DetectionBoxes_Recall/AR@100 (medium) = 0.0, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.3503029, Loss/BoxClassifierLoss/localization_loss = 0.25477797, Loss/RPNLoss/localization_loss = 2.490097, Loss/RPNLoss/objectness_loss = 0.30091414, Loss/total_loss = 3.3960922, global_step = 5627, learning_rate = 0.0, loss = 3.3960922
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5627: my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-5627
# I1009 01:08:15.118159 140205958432640 estimator.py:2109] Saving 'checkpoint_path' summary for global step 5627: my_models/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt-5627
# INFO:tensorflow:global_step/sec: 0.361089
# I1009 01:09:50.373345 140205958432640 basic_session_run_hooks.py:692] global_step/sec: 0.361089
# INFO:tensorflow:loss = 3.3807702, step = 5700 (276.940 sec)
# I1009 01:09:50.374986 140205958432640 basic_session_run_hooks.py:260] loss = 3.3807702, step = 5700 (276.940 sec)
